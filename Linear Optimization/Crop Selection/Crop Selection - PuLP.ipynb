# %%
pip install pulp
# Out:
# Collecting pulp
#   Downloading PuLP-2.9.0-py3-none-any.whl.metadata (5.4 kB)
# Downloading PuLP-2.9.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 69.0 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-2.9.0

# %%
from pulp import LpMaximize, LpProblem, LpVariable

# %%
# A farmer owns 60 acres of land. She can plant either wheat or corn. Based on current predictions, wheat will yield a profit of $200/acre while corn yields a profit of $300/acre.
# Each planted acre uses fertilizer and labor, wheat using 2 tons of fertilizer and 3 hours of worker time; corn using 4 tons of fertilizer and 2 hours of worker time.
# There are 100 hours of worker time and 120 tons of fertilizer available (costs of which are already included in the profit calculation).
# How should the farmer divide her land?

# %%
# Create the problem
model = LpProblem(name="maximize_profit", sense=LpMaximize)

# Define variables
x = LpVariable(name="Wheat", lowBound=0)
y = LpVariable(name="Corn", lowBound=0)

# Objective function: Maximize profit
model += 200 * x + 300 * y, "Total_Profit"

# Constraints
model += 2 * x + 4 * y <= 120, "Fertilizer_Constraint"
model += 3 * x + 2 * y <= 100, "Labour_Constraint"

# Solve the problem
status = model.solve()

# Output results
print(f"Optimal production of Wheat: {x.value()}")
print(f"Optimal production of Corn: {y.value()}")
print(f"Total Profit: ${model.objective.value()}")
# Out:
# Optimal production of Wheat: 20.0
# Optimal production of Corn: 20.0
# Total Profit: $10000.0
